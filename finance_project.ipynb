# %% [markdown]
# <a href="https://colab.research.google.com/github/Peeyush2/financeBuddy/blob/renuka_finance/finance_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Peeyush2/financeBuddy/master/finance_data.csv'
df1 = pd.read_csv(url)

# %%
df1
# Out:
#        user_id            name  age      location  family_size  \
# 0            0    Jaclyn Clark   67     West Lisa            5
# 1            0    Jaclyn Clark   67     West Lisa            5
# 2            0    Jaclyn Clark   67     West Lisa            5
# 3            0    Jaclyn Clark   67     West Lisa            5
# 4            0    Jaclyn Clark   67     West Lisa            5
# ...        ...             ...  ...           ...          ...
# 29608      999  Danielle Cohen   63  Kathleenland            1
# 29609      999  Danielle Cohen   63  Kathleenland            1
# 29610      999  Danielle Cohen   63  Kathleenland            1
# 29611      999  Danielle Cohen   63  Kathleenland            1
# 29612      999  Danielle Cohen   63  Kathleenland            1
#
#       transaction_date transaction_type       category      amount
# 0           04-03-2023          expense           rent  254.771452
# 1           01-12-2022           income         travel  368.126619
# ...

# %%
#Handling missing values:

missing_values = df1.isnull().sum()
print("Missing Values:")
print(missing_values)

#Observations: We can see that there are no missing values in the data
# Out:
# Missing Values:
# user_id             0
# name                0
# age                 0
# location            0
# family_size         0
# transaction_date    0
# transaction_type    0
# category            0
# amount              0
# dtype: int64
